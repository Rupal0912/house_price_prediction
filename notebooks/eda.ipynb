# %% [markdown]
# ***Data Analysis Phase***
# ***Understanding more about the data***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\house_price_prediction\data\train.csv')
test = pd.read_csv(r'C:\Users\Lenovo\OneDrive\Desktop\house_price_prediction\data\test.csv')

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.shape
# Out:
# (1460, 77)

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 77, dtype: int64

# %%
train = train.drop(['Id'], axis=1)

# %%
#Visualizations
#Plot distributions of key features
plt.figure(figsize=(10, 6))
sns.histplot(train['SalePrice'], kde = True)
plt.title("Distribution of Sale Price")
plt.xlabel("Sale Price")
plt.ylabel("Frequency")
plt.show()

# %%
numeric_train= train.select_dtypes(include=['int64', 'float64'])

# %%
#Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(numeric_train.corr(), cmap = 'coolwarm', annot = False)
plt.title("Correlation Matrix")
plt.show()
